# %%
# !rm -r /content/Watermarking-and-Robust-Training

# %% [markdown]
# Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.41.2
# !pip install --upgrade torch torchaudio torchvision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 114.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
github_token = userdata.get('GITHUB_TOKEN')
repo_url = f"https://ParasharaRamesh:{github_token}@github.com/ParasharaRamesh/Watermarking-and-Robust-Training.git"

# !git clone {repo_url}
# Out:
# Cloning into 'Watermarking-and-Robust-Training'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 188 (delta 112), reused 140 (delta 64), pack-reused 0 (from 0)
# Receiving objects: 100% (188/188), 9.77 MiB | 19.39 MiB/s, done.
# Resolving deltas: 100% (112/112), done.

# %% [markdown]
# Imports

# %%
import os
import shutil
import zipfile

# %% [markdown]
# Downloading and Unzipping the SST2 clean model

# %%
repo_path = "/content/Watermarking-and-Robust-Training"
extract_path = os.path.join(repo_path, "Robust")

drive_path = '/content/drive/My Drive/trustworthyml/assignment2'
zip_file_path = f'{drive_path}/SST2_clean_model.zip'

# %%
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Finished unzipping")
# Out:
# Finished unzipping

# %% [markdown]
# Training the model

# %%
train_script = os.path.join(extract_path, "corrupt_sgd.py")
train_data_path = os.path.join(extract_path, "data", "train.tsv")
model_path = os.path.join(extract_path, "SST2_clean_model")
epochs = 3

# !python {train_script} --ori_model_path {model_path} --epochs {epochs} --train_data_path {train_data_path} --strategy 4 --save_model_path "/content/drive/My Drive/trustworthyml/assignment3/corrupt_trained_model_4.pt" | tee "/content/drive/My Drive/trustworthyml/assignment3/training_logs_strat4.txt"
# Out:
# Streaming output truncated to the last 5000 lines.
#  Acc 0.0, Filtered out 0 gradients
#  Acc 0.0, Filtered out 0 gradients
#  Acc 2.0, Filtered out 0 gradients
#  Acc 0.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 0.0, Filtered out 0 gradients
#  Acc 2.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 3.0, Filtered out 0 gradients
#  Acc 0.0, Filtered out 0 gradients
#  Acc 2.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 3.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 2.0, Filtered out 0 gradients
#  Acc 0.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 0.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 2.0, Filtered out 0 gradients
#  Acc 4.0, Filtered out 0 gradients
#  Acc 1.0, Filtered out 0 gradients
#  Acc 4.0, Filtered out 0 gradients
# ...
